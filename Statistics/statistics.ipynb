# %% [markdown]
# Day 1:
#
# Statistics is a Branch of Maths that Deals with
#
#     Collection
#     Organization
#     Analysis
#     Interpretation
#     Presentation
#
# of Numerical Data

# %% [markdown]
# ----------

# %% [markdown]
# Day 2:
#
# Sampling =
#
#     https://www.kaggle.com/ (Download a Dataset)

# %%
import pandas as pd # pip install pandas
import sqlite3 # pip install db-sqlite3

# %%
# establish connection to the SQLite database
db = sqlite3.connect('sampleing.db')
cr = db.cursor()

# %%
# https://www.kaggle.com/datasets/dnyaneshyeole/flipkart-smartphones-dataset
df = pd.read_csv("data.csv") # Creates a Dataframe in a Tabular Maner
df # Prints the Data Frame
# Out:
#       brand             model               colour  original_price  \
# 0      VIVO      VIVO T1 44W            Starry Sky           19990
# 1     APPLE  APPLE IPHONE 11                 White           48900
# 2      VIVO      VIVO T1 44W       Midnight Galaxy           20990
# 3    XIAOMI       POCO M4 5G           Power Black           15999
# 4    XIAOMI         REDMI 10       Caribbean Green           14999
# ..      ...               ...                  ...             ...
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0               14499      4.5         87331     6044     4.0    128.0
# ...

# %%
df.to_sql('full_data', con=db, if_exists='replace', index=False) # write the Pandas DataFrame to the SQLite table
# Out:
# 836

# %%
dfh = df.head(4) # Default TOP 5 Rows Unless Mentioned in the Bracket
dfh
# Out:
#     brand             model           colour  original_price  \
# 0    VIVO      VIVO T1 44W        Starry Sky           19990
# 1   APPLE  APPLE IPHONE 11             White           48900
# 2    VIVO      VIVO T1 44W   Midnight Galaxy           20990
# 3  XIAOMI       POCO M4 5G       Power Black           15999
#
#    discounted_price  ratings  rating_count  reviews  memory  storage  \
# 0             14499      4.5         87331     6044     4.0    128.0
# 1             47199      4.6        184191    10818     NaN    128.0
# 2             15999      4.4         51365     3750     6.0    128.0
# 3             11999      4.2         53448     4185     4.0     64.0
#
#                  processor        rear_camera front_camera  display_size  \
# 0  Qualcomm Snapdragon 680  50MP + 2MP + 2MP          16MP         16.36
# 1            A Bionic Chip       12MP + 12MP          12MP         15.49
# 2  Qualcomm Snapdragon 680  50MP + 2MP + 2MP          16MP         16.36
# ...

# %%
dfh.to_sql('head_data', con=db, if_exists='replace', index=False) #ADDING TO THE DATABASE
# Out:
# 4

# %%
dft = df.tail(6) # Default BOTTOM 5 Rows Unless Mentioned in the Bracket
dft
# Out:
#       brand             model               colour  original_price  \
# 830  XIAOMI          POCO X2         Matrix Purple           17999
# 831  REALME  REALME GT NEO 2              NEO Blue           38999
# 832  REALME  REALME GT NEO 2             NEO Black           38999
# 833  REALME  REALME GT NEO 2             NEO Black           34999
# 834  REALME   REALME X50 PRO              Rust Red           17999
# 835  XIAOMI      POCO M2 PRO   Two Shades of Black           17999
#
#      discounted_price  ratings  rating_count  reviews  memory  storage  \
# 830             17999      4.5        271179    28996     6.0     64.0
# 831             35999      4.4          4430      628     NaN    256.0
# 832             35999      4.4          4430      628     NaN    256.0
# 833             31999      4.4         18194     2478     8.0    128.0
# 834             41999      4.4          8689     1232     8.0    128.0
# ...

# %%
dft.to_sql('tail_data', con=db, if_exists='replace', index=False)
# Out:
# 6

# %%
sql_query = """SELECT * FROM full_data WHERE brand='APPLE';""" #SAMPLING USING SQL QUERIES
# executing our sql query
cr.execute(sql_query)
# printing all tables list
data = cr.fetchall()
print(data)
# Out:
# [('APPLE', 'APPLE IPHONE 11 ', 'White', 48900, 47199, 4.6, 184191, 10818, None, 128.0, 'A Bionic Chip', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 11 ', 'White', 43900, 40999, 4.6, 184191, 10818, None, 64.0, 'A Bionic Chip', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 14 ', 'Midnight', 79900, 71999, 4.7, 16010, 686, None, 128.0, 'A Bionic Chip,  Core', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 14 ', 'Starlight', 79900, 71999, 4.7, 16010, 686, None, 128.0, 'A Bionic Chip,  Core', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 11 ', 'Black', 43900, 40999, 4.6, 184191, 10818, None, 64.0, 'A Bionic Chip', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 14 ', 'Purple', 79900, 71999, 4.7, 16010, 686, None, 128.0, 'A Bionic Chip,  Core', '12MP + 12MP ', ' 12MP', 15.49, None, None), ('APPLE', 'APPLE IPHONE 14 ', 'Blue', 79900, 71999, 4.7, 16010, 686, None, 128.0, 'A Bionic
# ...

# %%
# convert data to a pandas DataFrame
df_apples_sample = pd.DataFrame(data)
df_apples_sample
# Out:
#        0                         1            2       3       4    5       6   \
# 0   APPLE          APPLE IPHONE 11         White   48900   47199  4.6  184191
# 1   APPLE          APPLE IPHONE 11         White   43900   40999  4.6  184191
# 2   APPLE          APPLE IPHONE 14      Midnight   79900   71999  4.7   16010
# 3   APPLE          APPLE IPHONE 14     Starlight   79900   71999  4.7   16010
# 4   APPLE          APPLE IPHONE 11         Black   43900   40999  4.6  184191
# 5   APPLE          APPLE IPHONE 14        Purple   79900   71999  4.7   16010
# 6   APPLE          APPLE IPHONE 14          Blue   79900   71999  4.7   16010
# 7   APPLE          APPLE IPHONE 11         Black   48900   47999  4.6  184191
# 8   APPLE          APPLE IPHONE 12         Black   64900   56999  4.6  186979
# 9   APPLE          APPLE IPHONE 13          Pink   69900   61999  4.7  190651
# 10  APPLE          APPLE IPHONE 13          Blue   69900   61999  4.7  190651
# ...

# %%
# close the SQLite connection
db.close()

# %% [markdown]
# ----------

# %% [markdown]
# Day 3:
#     Measures of Central Tendency (Mean, Meadian & Mode)

# %%
import pandas as pd #ALREDY IMPORTED
import statistics as st

# %%
df=pd.read_csv("centraltendancy.csv",header=None,names=["data"])
df
# Out:
#        data
# 0    1000.0
# 1     828.0
# 2     711.0
# 3     700.0
# 4     644.0
# ..      ...
# 295   308.6
# 296   308.2
# 297   308.0
# 298   308.0
# 299   308.0
#
# [300 rows x 1 columns]

# %%
x=df["data"]
# x=list(df["data"])
# x=df["data"].to_list()
x
# Out:
# 0      1000.0
# 1       828.0
# 2       711.0
# 3       700.0
# 4       644.0
#         ...
# 295     308.6
# 296     308.2
# 297     308.0
# 298     308.0
# 299     308.0
# Name: data, Length: 300, dtype: float64

# %%
dfm = st.mean(x)
# dfm=st.geometric_mean(x)
# dfm=st.harmonic_mean(x)
dfm
# Out:
# 397.25266666666664

# %%
dfm=st.mode(x)
dfm
# Out:
# 350.0

# %%
dfm=st.median(x)
dfm
# Out:
# 369.0

# %%
'''
MEAN =
MODE =
MEDIAN =
'''
# Out:
# '\nMEAN =\nMODE =\nMEDIAN =\n'

# %% [markdown]
# ----------

# %% [markdown]
# Day 4:
#     Bar Graph, Scatter Plot & Pie Charts

# %%
import pandas as pd #ALREDY IMPORTED
import matplotlib.pyplot as plt # pip install matplotlib

# %% [markdown]
#     BARGRAPH

# %%
df = pd.read_csv("bargraph.csv")
df
# Out:
#       Name  Books Read
# 0    Alice           8
# 1      Bob           5
# 2  Charlie          11

# %%
plt.bar(df['Name'],df['Books Read'])
plt.xlabel("Books")
plt.ylabel("Number")
plt.title("Number of Books Read Per Person.")
plt.show() # Display the graph

# %% [markdown]
#     PIECHART

# %%
df = pd.read_csv("piechart.csv")
df
# Out:
#        Fruit  Qty
# 0      Apple   25
# 1     Banana   35
# 2     Orange   20
# 3      Mango   15
# 4  Pineapple    5

# %%
plt.pie(df["Qty"],labels=df["Fruit"])
plt.title(r"% of Each Fruit")
plt.show()

# %% [markdown]
#     SCATTERPLOT

# %%
df = pd.read_csv("scatterplot.csv")
df
# Out:
#     X   Y
# 0   1   5
# 1   2   7
# 2   3   6
# 3   4  10
# 4   5   9
# 5   6  12
# 6   7  13
# 7   8  11
# 8   9  15
# 9  10  14

# %%
x = df["X"]
y = df["Y"]

# %%
plt.scatter(x,y)
plt.title("Scatter Plot Example")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ----------

# %% [markdown]
# Day 5:
#
# LINEAR Regression (Y = mX + c)

# %%
import pandas as pd #ALREDY IMPORTED
import matplotlib.pyplot as plt #ALREDY IMPORTED
from sklearn.linear_model import LinearRegression # pip install scikit-learn

# %%
# Load the dataset into a pandas DataFrame
df = pd.read_csv('linear_regression.csv')
df
# Out:
#    Height (in)  Weight (lbs)
# 0           65           120
# 1           68           145
# 2           70           160
# 3           72           180
# 4           61            95
# 5           64           115
# 6           73           210
# 7           69           165
# 8           75           250
# 9           62           105

# %%
# Extract the height and weight columns as arrays
X = df['Height (in)'].values.reshape(-1, 1) 
y = df['Weight (lbs)'].values #Column 2 Predict
print("x\n",X)
print("\n-------------------------\n")
print("y\n",y)
# Out:
# x
#  [[65]
#  [68]
#  [70]
#  [72]
#  [61]
#  [64]
#  [73]
#  [69]
#  [75]
#  [62]]
#
# -------------------------
#
# y
#  [120 145 160 180  95 115 210 165 250 105]

# %%
# Create a scatter plot of the data
plt.scatter(X, y)
plt.xlabel('Height (in)')
plt.ylabel('Weight (lbs)')
plt.title('Height vs Weight')
plt.show()

# %%
# Create a linear regression model and fit it to the data
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
m = model.coef_[0]
c = model.intercept_
formula = "y = "+str(m)+"*x + "+str(c)+"" # Y = mX + c
# print(X)
# print(y)
print(formula)
# Out:
# y = 9.97803806734993*x + -523.0087847730603

# %%
new_height = 73 # int(input("Enter a New Height Value = "))
new_weight = model.predict([[new_height]])

print('Predicted weight for height', new_height, ':', int(new_weight[0]),"(APPROX)")
# Out:
# Predicted weight for height 73 : 205 (APPROX)

# %%
# # model = LinearRegression()
# model.fit(y,X)

# %% [markdown]
# ----------

# %% [markdown]
# Day 6:
#
# Measures of Dispersion ( Range, Variance [Error Measure], Standard Deviation)
#
#     Variance and error measure are not the same, although they are related concepts.
#     Variance is a measure of the variability or spread of a set of data points around the mean or expected value. It is calculated as the average of the squared differences of each data point from the mean. In statistics, variance is often used as a measure of the amount of information contained in a data set.
#     On the other hand, an error measure is a metric that quantifies the difference between the observed values and the predicted values. It is commonly used in machine learning and statistical modeling to evaluate the accuracy of a model's predictions. Examples of error measures include mean squared error (MSE), root mean squared error (RMSE), mean absolute error (MAE), etc.
#     While variance is a measure of the spread of the data, error measures are used to quantify the performance of a model in making predictions on new data. However, there is a relationship between the two concepts, as high variance in a model can lead to overfitting, which in turn can result in high prediction errors on new data.

# %%
import numpy as np # pip install numpy

# %%
data = np.array([3, 5, 6, 7, 9, 12])
data
# Out:
# array([ 3,  5,  6,  7,  9, 12])

# %%
"""
l = sorted(data.tolist())
data_range = l[-1] - l[0] #MAXIMUM - MINIMUM values
"""
data_range = np.ptp(data) # calculate the range of the array

# print the range
print("Range =", data_range)
# Out:
# Range = 9

# %%
'''
In statistics, when we use a sample to estimate the parameters of the population, we typically use the sample standard deviation and variance instead of the population standard deviation and variance. However, since the sample is only a subset of the population, the sample statistics tend to underestimate the population parameters.
To adjust for this bias, we use the Bessel's correction, which involves dividing the sum of squared deviations by n-1 instead of n. The parameter "ddof" stands for "Delta Degrees of Freedom" and determines the value to subtract from the sample size to obtain the degrees of freedom. When we set ddof=1, we are indicating that we want to use the Bessel's correction and that we have one less degree of freedom compared to the total number of samples.
In other words, when ddof=1, we are estimating the variance of a sample from a larger population, and we are using the sample variance as an unbiased estimator of the population variance. When ddof=0, we are computing the variance of a population from the data, and there is no need to correct for bias.
'''
# Out:
# '\nIn statistics, when we use a sample to estimate the parameters of the population, we typically use the sample standard deviation and variance instead of the population standard deviation and variance. However, since the sample is only a subset of the population, the sample statistics tend to underestimate the population parameters.\nTo adjust for this bias, we use the Bessel\'s correction, which involves dividing the sum of squared deviations by n-1 instead of n. The parameter "ddof" stands for "Delta Degrees of Freedom" and determines the value to subtract from the sample size to obtain the degrees of freedom. When we set ddof=1, we are indicating that we want to use the Bessel\'s correction and that we have one less degree of freedom compared to the total number of samples.\nIn other words, when ddof=1, we are estimating the variance of a sample from a larger population, and we are using the sample variance as an unbiased estimator of the population variance. When ddof=0, we are
# ...

# %%
variance = np.var(data, ddof=1 ) #
print("Variance =",variance)
# Out:
# Variance = 10.0

# %%
std_deviation = np.std(data, ddof=1) #
print("Standard Deviation =",std_deviation)
# Out:
# Standard Deviation = 3.1622776601683795

# %% [markdown]
# ----------

# %% [markdown]
# Day 7:
#     Correlation

# %%
import pandas as pd #ALREDY IMPORTED
import matplotlib.pyplot as plt #ALREDY IMPORTED
import seaborn as sns # pip install seaborn

# %%
# Load the Auto MPG dataset
auto_df = pd.read_csv('correlation.csv')# https://www.kaggle.com/datasets/uciml/autompg-dataset
auto_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# Calculate the correlation matrix
corr_matrix = auto_df.corr()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_21952\396164467.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = auto_df.corr()

# %%
# Visualize the correlation matrix using a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Auto MPG Dataset')
plt.show() #We use seaborn's heatmap function to visualize the correlation matrix as a heatmap, with the strength of the correlation indicated by the color of the cells. The annot=True argument adds the numerical values to each cell of the heatmap, and cmap='coolwarm' sets the color map to a blue-to-red spectrum.

# %%
sns.scatterplot(x='weight', y='mpg', data=auto_df)
plt.title('Scatterplot of MPG vs. Weight')
plt.show() #to visualize the relationship between them

# %% [markdown]
# r = (nΣxy - ΣxΣy) / sqrt[(nΣx^2 - (Σx)^2)(nΣy^2 - (Σy)^2)]
#
#     n is the number of data points
#     Σ denotes the sum of the values
#     x and y are the two variables
#     xy is the product of the corresponding values of x and y
#
# Note:- Correlation is Always between -1 to +1

# %% [markdown]
# ----------

# %% [markdown]
# Day 8:
#
# Outliers

# %%
import pandas as pd #ALREDY IMPORTED
import seaborn as sns #ALREDY IMPORTED
import numpy as np #ALREDY IMPORTED

# %%
df = pd.read_csv('outliers.csv', header=0)
df
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0     24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1     21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2     34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3     33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4     36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
# ..     ...         ...         ...       ...       ...   ...    ...    ...
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
# ...

# %%
df.shape
# Out:
# (506, 19)

# %%
df.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677083   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
uv = np.percentile(df.n_hot_rooms,[99])[0]
uv
# Out:
# 15.39952

# %%
df[(df.n_hot_rooms>uv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df.n_hot_rooms[(df.n_hot_rooms > 3*uv)] = 3*uv
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_21952\4019091346.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.n_hot_rooms[(df.n_hot_rooms > 3*uv)] = 3*uv

# %%
df[(df.n_hot_rooms>uv)] #CHECKING AFTER CHANGING
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394     46.19856
# 166   2.31   1.86      25.3       3.70     YES       8.300     15.40000
# 204   5.28   4.99      25.3       2.88     YES       8.900     15.40000
# 267   2.43   2.52      27.0       7.44     YES       8.000     15.40000
# 369   1.65   0.94      19.8       3.73     YES       6.700     15.40000
# ...

# %%
lv = np.percentile(df.rainfall,[1])[0]

# %%
df[(df.rainfall< lv)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df.rainfall[(df.rainfall <0.3*lv)] = 0.3*lv
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_21952\2206257297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rainfall[(df.rainfall <0.3*lv)] = 0.3*lv

# %%
df[(df.rainfall< lv)] #CHECKING AFTER CHANGING
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         6     YES  0.044019

# %% [markdown]
# ----------

# %% [markdown]
# Day 9:

# %% [markdown]
#     Predictive Time Series Forecasting

# %%
import pandas as pd #ALREDY IMPORTED
import numpy as np #ALREDY IMPORTED
import matplotlib.pyplot as plt #ALREDY IMPORTED
from statsmodels.tsa.arima.model import ARIMA # pip install statsmodels
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf #ALREDY IMPORTED

# %%
# Load the time series data
data = pd.read_csv('P_redict.csv', index_col='Month', parse_dates=True)
data
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
# Plot the time series
plt.plot(data)
plt.title('My Time Series')
plt.show()

# %%
# Take the first difference to make the time series stationary
diff = data.diff().dropna()
diff
# Out:
#             Passengers
# Month
# 1949-02-01         6.0
# 1949-03-01        14.0
# 1949-04-01        -3.0
# 1949-05-01        -8.0
# 1949-06-01        14.0
# ...                ...
# 1960-08-01       -16.0
# 1960-09-01       -98.0
# 1960-10-01       -47.0
# 1960-11-01       -71.0
# 1960-12-01        42.0
#
# [143 rows x 1 columns]

# %%
# Plot the differenced time series
plt.plot(diff)
plt.title('Differenced Time Series')
plt.show()

# %%
# Plot the ACF and PACF to determine the orders of p and q
plot_acf(diff)
plot_pacf(diff)
plt.show()
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
'''
Autocorrelation (ACF) and partial autocorrelation (PACF) are functions used to describe the correlation between a time series and its lags.

Autocorrelation is a measure of how a time series is correlated with itself at different lags. Specifically, it measures the correlation between a time series and its own values at previous time steps, for various lags. The autocorrelation function (ACF) is a plot of these correlations as a function of the lag. The ACF is a useful tool for identifying patterns and trends in the data, such as seasonal patterns or trends.

Partial autocorrelation, on the other hand, measures the correlation between a time series and its own values at previous time steps, but after removing the effects of shorter lags. This is useful for identifying the specific lag(s) that have a significant impact on the current value of the time series. The partial autocorrelation function (PACF) is a plot of these correlations as a function of the lag, after accounting for the effects of shorter lags.

In summary, both ACF and PACF are tools used to explore and understand the relationship between a time series and its own values at different lags. They are important for identifying the order of the ARIMA model to fit to the data, which in turn helps in forecasting the time series accurately.
'''
# Out:
# '\nAutocorrelation (ACF) and partial autocorrelation (PACF) are functions used to describe the correlation between a time series and its lags.\n\nAutocorrelation is a measure of how a time series is correlated with itself at different lags. Specifically, it measures the correlation between a time series and its own values at previous time steps, for various lags. The autocorrelation function (ACF) is a plot of these correlations as a function of the lag. The ACF is a useful tool for identifying patterns and trends in the data, such as seasonal patterns or trends.\n\nPartial autocorrelation, on the other hand, measures the correlation between a time series and its own values at previous time steps, but after removing the effects of shorter lags. This is useful for identifying the specific lag(s) that have a significant impact on the current value of the time series. The partial autocorrelation function (PACF) is a plot of these correlations as a function of the lag, after accounting f
# ...

# %%
# Fit the ARIMA model with orders (1,1,1)
model = ARIMA(data, order=(1,1,1))
result = model.fit()

# Print the summary of the model
print(result.summary())
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:             Passengers   No. Observations:                  144
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -694.341
# ...

# %%
# Make predictions for the next 10 periods
forecast = result.forecast(steps=10)
forecast
# Out:
# 1961-01-01    475.735059
# 1961-02-01    454.996073
# 1961-03-01    464.830415
# 1961-04-01    460.167010
# 1961-05-01    462.378378
# 1961-06-01    461.329756
# 1961-07-01    461.827008
# 1961-08-01    461.591213
# 1961-09-01    461.703026
# 1961-10-01    461.650005
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
# Plot the forecasted values
plt.plot(data)
plt.plot(forecast, color='red')
plt.title('Forecasted Time Series')
plt.show()

# %% [markdown]
#     P-Value

# %%
from statsmodels.tsa.stattools import adfuller #ALREDY IMPORTED

# %%
result = adfuller(data['Passengers']) # <-- Access the 'Passengers' column
result
# Out:
# (0.8153688792060441,
#  0.9918802434376409,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: 0.815369
# p-value: 0.991880

# %%
if result[1] > 0.05:
    print('The time series is not stationary')
else:
    print('The time series is stationary')
# Out:
# The time series is not stationary

# %% [markdown]
# ----------

# %% [markdown]
# Day 10:
#     K means clustering

# %%
import pandas as pd #ALREDY IMPORTED
import numpy as np #ALREDY IMPORTED
import matplotlib.pyplot as plt #ALREDY IMPORTED
import seaborn as sns #ALREDY IMPORTED
from sklearn.cluster import KMeans #ALREDY IMPORTED

# %%
sns.set()

# %%
data = pd.read_csv('k_means.csv')
data
# Out:
#      Country  Latitude  Longitude Language
# 0        USA     44.97    -103.77  English
# 1     Canada     62.40     -96.80  English
# 2     France     46.75       2.40   French
# 3         UK     54.01      -2.53  English
# 4    Germany     51.15      10.40   German
# 5  Australia    -25.45     133.11  English

# %%
plt.scatter(data['Longitude'],data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show #It will Look Like where the Actual Locations are.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = data.iloc[:,1:3] #Rows,Colums (SLICING)
x
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40
# 5    -25.45     133.11

# %%
k = 3 #Current Number of Clusters.
kmeans = KMeans(k)

# %%
kmeans.fit(x)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
identified_clusters = kmeans.fit_predict(x)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#      Country  Latitude  Longitude Language  Cluster
# 0        USA     44.97    -103.77  English        0
# 1     Canada     62.40     -96.80  English        0
# 2     France     46.75       2.40   French        1
# 3         UK     54.01      -2.53  English        1
# 4    Germany     51.15      10.40   German        1
# 5  Australia    -25.45     133.11  English        2

# %%
plt.scatter(data_with_clusters['Longitude'],data_with_clusters['Latitude'],c=data_with_clusters['Cluster'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %%
"""
K is the Number of Clusters we wana Have.
Choose a Centroid (BASED ON PRIOR KNOWLEDGE ON THE DATA).
Assign Each Point to a Centroid (by their Euclidian Distance).
Adjust the Centroid.
Reassign the Points According to the new Centroids.
Then Readjust the Centroids.
Do This Until U Cant Anymore.
"""
# Out:
# '\nK is the Number of Clusters we wana Have.\nChoose a Centroid (BASED ON PRIOR KNOWLEDGE ON THE DATA).\nAssign Each Point to a Centroid (by their Euclidian Distance).\nAdjust the Centroid.\nReassign the Points According to the new Centroids.\nThen Readjust the Centroids.\nDo This Until U Cant Anymore.\n'

# %% [markdown]
#     Neural Network

# %%
'''
(PART OF DEEP LEARNING)
Neural Network: A neural network is a type of machine learning model inspired by the structure and function of the human brain. It consists of layers of interconnected nodes, or neurons, which are used to process and analyze data. Neural networks can be used for a variety of tasks, such as image recognition, natural language processing, and predictive modeling.
'''
# Out:
# '\n(PART OF DEEP LEARNING)\nNeural Network: A neural network is a type of machine learning model inspired by the structure and function of the human brain. It consists of layers of interconnected nodes, or neurons, which are used to process and analyze data. Neural networks can be used for a variety of tasks, such as image recognition, natural language processing, and predictive modeling.\n'

# %% [markdown]
#     Non Linear Regression

# %%
"""
Nonlinear regression is a type of statistical modeling that allows for more complex relationships between the independent and dependent variables compared to linear regression. There are several types of nonlinear regression, including:

-Polynomial regression
-Logistic regression
-Exponential regression
-Power regression
-Sigmoidal regression
-Mltiple linear regression
-Dision tree regression
-Sport vector regression
"""
# Out:
# '\nNonlinear regression is a type of statistical modeling that allows for more complex relationships between the independent and dependent variables compared to linear regression. There are several types of nonlinear regression, including:\n\n-Polynomial regression\n-Logistic regression\n-Exponential regression\n-Power regression\n-Sigmoidal regression\n-Mltiple linear regression\n-Dision tree regression\n-Sport vector regression\n'

# %% [markdown]
# ----------
