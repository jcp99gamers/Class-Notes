# %% [markdown]
# Calculator

# %%
a = int(input("Enter a Number"))
b = int(input("Enter a Number"))
c = input("Enter a Operator")
if (c=="+"):
    print(a+b)
elif(c=="-"):
    print(a-b)
elif(c=="*"):
    print(a*b)
elif(c=="/"):
    print(a/b)

# %%
a = int(input("Enter a Number"))
b = int(input("Enter a Number"))
c = input("Enter a Operator")
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    print(a+b)
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    print(a-b)
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    print(a*b)
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide") and b!=0):
    print(a/b)

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
a = int(input("Enter a Number"))
b = int(input("Enter a Number"))
c = input("Enter a Operator")
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    add(a+b)
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    sub(a-b)
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    mul(a*b)
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide") and b!=0):
    div(a/b)

# %%
class calc():
    def __init__(self):
        self.a = a
        self.b = b
    def add(self):
        print(self.a+self.b)
    def sub(self):
        print(self.a-self.b)
    def mul(self):
        print(self.a*self.b)
    def div(self):
        print(self.a/self.b)
a = int(input("Enter a Number"))
b = int(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide") and b!=0):
    div()

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        print(self.a+self.b)
    def sub(self):
        print(self.a-self.b)
    def mul(self):
        print(self.a*self.b)
    def div(self):
        print(self.a/self.b)

a = int(input("Enter a Number"))
b = int(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide") and b!=0):
    div()

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        print(self.a+self.b)
    def sub(self):
        print(self.a-self.b)
    def mul(self):
        print(self.a*self.b)
    def div(self):
        print(self.a/self.b)

a = float(input("Enter a Number"))
b = float(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide") and b!=0):
    div()

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        print(self.a+self.b)
    def sub(self):
        print(self.a-self.b)
    def mul(self):
        print(self.a*self.b)
    def div(self):
        try:
            d = self.a/self.b
        except Exception as e:
            d = str(Exception)
        finally:
            print(d)

a = float(input("Enter a Number"))
b = float(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide")): # and b!=0
    div()

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        return self.a+self.b
    def sub(self):
        return self.a-self.b
    def mul(self):
        return self.a*self.b
    def div(self):
        try:
            d = self.a/self.b
        except Exception as e:
            d = str(Exception)
        finally:
            return d

a = float(input("Enter a Number"))
b = float(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    print(add())
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    print(sub())
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    print(mul())
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide")): # and b!=0
    print(div())

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        return self.a+self.b
    def sub(self):
        return self.a-self.b
    def mul(self):
        return self.a*self.b
    def div(self):
        try:
            d = self.a/self.b
        except Exception as e:
            d = str(Exception)
        finally:
            return d

a = float(input("Enter a Number"))
b = float(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    ans = add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    ans = sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    ans = mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide")): # and b!=0
    ans = div()

print(ans)

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        return self.a+self.b
    def sub(self):
        return self.a-self.b
    def mul(self):
        return self.a*self.b
    def div(self):
        try:
            d = self.a/self.b
        except Exception as e:
            d = str(Exception)
        finally:
            return d

a = float(input("Enter a Number"))
b = float(input("Enter a Number"))
c = input("Enter a Operator")
obj = calc(a,b)
if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
    ans = add()
elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
    ans = sub()
elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
    ans = mul()
elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide")): # and b!=0
    ans = div()
else:
    ans = "Wrong Input for Operator"
    
print(ans)

# %%
class vals():
    def __init__(self):
        self.a = a
        self.b = b    
class calc(vals):
    def __init__(self):
        super().__init__(a,b) # vals.__init__(self,a,b)
    def add(self):
        return self.a+self.b
    def sub(self):
        return self.a-self.b
    def mul(self):
        return self.a*self.b
    def div(self):
        try:
            d = self.a/self.b
        except Exception as e:
            d = str(Exception)
        finally:
            return d

while True:
    a = float(input("Enter a Number"))
    b = float(input("Enter a Number"))
    c = input("Enter a Operator")
    obj = calc(a,b)
    if (c=="+" or c=="Add" or c=="ADD" or c=="add"):
        ans = add()
        pass
    elif(c=="-" or c=="Minus" or c=="MINUS" or c=="minus"):
        ans = sub()
        pass
    elif(c=="*" or c=="Multiply" or c=="MULTIPLY" or c=="multiply"):
        ans = mul()
        pass
    elif((c=="/" or c=="Divide" or c=="DIVIDE" or c=="divide")): # and b!=0
        ans = div()
        pass
    else:
        print("Wrong Input for Operator")
        break
        
    print(ans)
    continue
